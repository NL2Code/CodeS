# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import os


x = [3, 7, 13, 15, 33, 34]

# 10.6, 16.3, 21.3, 26.2
dscoder_values = [np.nan, 14.6, np.nan, np.nan, 15.04, np.nan]
dscoder_values_x = np.array(x)[~np.isnan(dscoder_values)]
dscoder_values_y = np.array(dscoder_values)[~np.isnan(dscoder_values)]
plt.plot(
    dscoder_values_x, 
    dscoder_values_y, 
    color='xkcd:coral', # ['xkcd:sky blue', 'xkcd:light green', 'xkcd:coral', 'xkcd:light cyan', 'xkcd:lavender', 'xkcd:light yellow', 'xkcd:silver', 'xkcd:light grey']
    linewidth=2, 
    label='DeepSeekCoder', 
    marker='o',
    markersize=7,
    linestyle='-' # ['-', '--', '-.', ':', '', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted']
)

starcoder2_values = [14.15, 15.0, np.nan, 15.44, np.nan, np.nan]
starcoder2_values_x = np.array(x)[~np.isnan(starcoder2_values)]
starcoder2_values_y = np.array(starcoder2_values)[~np.isnan(starcoder2_values)]
plt.plot(
    starcoder2_values_x,
    starcoder2_values_y,
    color='xkcd:sky blue', # ['xkcd:sky blue', 'xkcd:light green', 'xkcd:coral', 'xkcd:light cyan', 'xkcd:lavender', 'xkcd:light yellow', 'xkcd:silver', 'xkcd:light grey']
    linewidth=2, 
    label='StarCoder2', 
    marker='x', 
    markersize=7,
    linestyle='-' # ['-', '--', '-.', ':', '', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted']
)

codellama_values = [np.nan, 14.8, 16.4, np.nan, np.nan, 17.7]
codellama_values_x = np.array(x)[~np.isnan(codellama_values)]
codellama_values_y = np.array(codellama_values)[~np.isnan(codellama_values)]
plt.plot(
    codellama_values_x, 
    codellama_values_y, 
    color='xkcd:mustard yellow', # ['xkcd:sky blue', 'xkcd:light green', 'xkcd:coral', 'xkcd:light cyan', 'xkcd:lavender', 'xkcd:light yellow', 'xkcd:silver', 'xkcd:light grey']
    linewidth=2, 
    label='CodeLlama', 
    marker='s', # ["o", "v", "^", "<", ">", "s", "p", "P", "*", "h", "H", "+", "x", "X", "D", "d", "|", "_"]
    markersize=7,
    linestyle='-' # ['-', '--', '-.', ':', '', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted']
)

plt.ylabel('SketchBLEU (%)')
plt.xlabel('Model Size (Billion)')

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

plt.gca().xaxis.set_ticks_position('bottom')
plt.gca().yaxis.set_ticks_position('left')

plt.rcParams['figure.figsize'] = (4, 2.5)

plt.xticks(np.arange(0, 35, 10))

plt.legend()

plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.savefig('./various_model_and_size.pdf', bbox_inches='tight', pad_inches=0.05, format='pdf', dpi=600)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import os


fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(9, 3.3))

x = [3, 7, 13, 15, 33, 34]

# Deepseekcoder
10.12, 11.29
# StarCoder2
6.52, 18.79, 24.92
# CodeLlama
8.80, 10.80, 13.99


dscoder_values = [np.nan, 10.12, np.nan, np.nan, 11.29, np.nan]
dscoder_values_x = np.array(x)[~np.isnan(dscoder_values)]
dscoder_values_y = np.array(dscoder_values)[~np.isnan(dscoder_values)]
axs[0].plot(
    dscoder_values_x, 
    dscoder_values_y, 
    color='xkcd:coral', # ['xkcd:sky blue', 'xkcd:light green', 'xkcd:coral', 'xkcd:light cyan', 'xkcd:lavender', 'xkcd:light yellow', 'xkcd:silver', 'xkcd:light grey']
    linewidth=2, 
    label='DeepSeekCoder', 
    marker='o',
    markersize=7,
    linestyle='-' # ['-', '--', '-.', ':', '', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted']
)

starcoder2_values = [6.52, 18.79, np.nan, 24.92, np.nan, np.nan]
starcoder2_values_x = np.array(x)[~np.isnan(starcoder2_values)]
starcoder2_values_y = np.array(starcoder2_values)[~np.isnan(starcoder2_values)]
axs[0].plot(
    starcoder2_values_x,
    starcoder2_values_y,
    color='xkcd:sky blue', # ['xkcd:sky blue', 'xkcd:light green', 'xkcd:coral', 'xkcd:light cyan', 'xkcd:lavender', 'xkcd:light yellow', 'xkcd:silver', 'xkcd:light grey']
    linewidth=2, 
    label='StarCoder2', 
    marker='x', 
    markersize=7,
    linestyle='-' # ['-', '--', '-.', ':', '', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted']
)

codellama_values = [np.nan, 8.80, 10.80, np.nan, np.nan, 13.99]
codellama_values_x = np.array(x)[~np.isnan(codellama_values)]
codellama_values_y = np.array(codellama_values)[~np.isnan(codellama_values)]
axs[0].plot(
    codellama_values_x, 
    codellama_values_y, 
    color='xkcd:mustard yellow', # ['xkcd:sky blue', 'xkcd:light green', 'xkcd:coral', 'xkcd:light cyan', 'xkcd:lavender', 'xkcd:light yellow', 'xkcd:silver', 'xkcd:light grey']
    linewidth=2, 
    label='CodeLlama', 
    marker='s', # ["o", "v", "^", "<", ">", "s", "p", "P", "*", "h", "H", "+", "x", "X", "D", "d", "|", "_"]
    markersize=7,
    linestyle='-' # ['-', '--', '-.', ':', '', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted']
)

font_size = 12
font_size_legend = 12

axs[0].set_ylabel('Improvement SketchBLEU (%)', fontsize=font_size)
axs[0].set_xlabel('(a) Model Size (Billion)', fontsize=font_size)
axs[0].xaxis.set_tick_params(labelsize=font_size)
axs[0].yaxis.set_tick_params(labelsize=font_size)

axs[0].spines['top'].set_visible(False)
axs[0].spines['right'].set_visible(False)
axs[0].spines['bottom'].set_color('black')
axs[0].spines['left'].set_color('black')
axs[0].xaxis.set_ticks_position('bottom')
axs[0].yaxis.set_ticks_position('left')
axs[0].grid(True, which='both', linestyle='--', linewidth=0.5)
axs[0].legend(prop={'size': font_size_legend})


# ---

noise_rate = [0, 20, 40, 60, 80, 100]

starcoder_impro_pass1 = [45.59, 37.51, 43.25, 50.21, 53.61, 54.39]
axs[1].plot(
    noise_rate, 
    starcoder_impro_pass1, 
    color='xkcd:lavender', # ['xkcd:sky blue', 'xkcd:light green', 'xkcd:coral', 'xkcd:light cyan', 'xkcd:lavender', 'xkcd:light yellow', 'xkcd:silver', 'xkcd:light grey']
    linewidth=2, 
    label='CodeLlama 7B', 
    marker='s',
    markersize=7,
    linestyle='-' # ['-', '--', '-.', ':', '', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted']
)

starcoder_impro_pass2 = [46.43, 41.24, 47.84, 53.31, 56.21, 57.23]
axs[1].plot(
    noise_rate, 
    starcoder_impro_pass2, 
    color='xkcd:light green', # ['xkcd:sky blue', 'xkcd:light green', 'xkcd:coral', 'xkcd:light cyan', 'xkcd:lavender', 'xkcd:light yellow', 'xkcd:silver', 'xkcd:light grey']
    linewidth=2, 
    label='CodeLlama 13B', 
    marker='s',
    markersize=7,
    linestyle='-' # ['-', '--', '-.', ':', '', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted']
)

starcoder_impro_pass3 = [49.32, 44.24, 42.51, 54.21, 62.13, 63.31]
axs[1].plot(
    noise_rate,
    starcoder_impro_pass3,
    color='xkcd:silver', # ['xkcd:sky blue', 'xkcd:light green', 'xkcd:coral', 'xkcd:light cyan', 'xkcd:lavender', 'xkcd:light yellow', 'xkcd:silver', 'xkcd:light grey']
    linewidth=2,
    label='CodeLlama 34B',
    marker='s',
    markersize=7,
    linestyle='-' # ['-', '--', '-.', ':', '', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted']
)

axs[1].set_ylabel('SketchBLEU (%)', fontsize=font_size)
axs[1].set_xlabel('(b) Repository Number of Training', fontsize=font_size)
axs[1].xaxis.set_tick_params(labelsize=font_size)
axs[1].yaxis.set_tick_params(labelsize=font_size)

axs[1].spines['top'].set_visible(False)
axs[1].spines['right'].set_visible(False)
axs[1].spines['bottom'].set_color('black')
axs[1].spines['left'].set_color('black')
axs[1].xaxis.set_ticks_position('bottom')
axs[1].yaxis.set_ticks_position('left')
axs[1].grid(True, which='both', linestyle='--', linewidth=0.5)
axs[1].legend(prop={'size': font_size_legend})

# fig.subplots_adjust(wspace=0.25)


plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.savefig('./various_model_and_size_and_repo_nums.pdf', bbox_inches='tight', format='pdf', dpi=600)

# %%
# Out:
# (49.32, 51.24, 53.51, 54.21, 62.13, 63.31)

# %%
round(63.31-49.32, 2)
# Out:
# 13.99
